# %% [markdown]
# <a href="https://colab.research.google.com/github/SR-basic/pproject/blob/main/%EB%A0%88%EB%AA%A8%EB%84%A4%EC%9D%B4%EB%93%9C_%ED%8C%90%EB%A7%A4%EB%9F%89%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf


파일경로 = 'lemonade.csv'
데이터 = pd.read_csv(파일경로)

#독립변수, 종속변수 분리

독립 = 데이터[['온도']]
종속 = 데이터[['판매량']]
print(독립.shape, 종속.shape)
# Out:
# (6, 1) (6, 1)

# %%
x=tf.keras.layers.Input(shape=[1])
y=tf.keras.layers.Dense(1)(x)
model=tf.keras.models.Model(x,y)
model.compile(loss='mse')

# %%
model.fit(독립,종속,epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 892.2093
# Epoch 2/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 890.8122
# Epoch 3/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 889.4162
# Epoch 4/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 888.0213
# Epoch 5/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 886.6274
# Epoch 6/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 885.2348
# Epoch 7/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 883.8432
# Epoch 8/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 882.4525
# Epoch 9/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 881.0632
# Epoch 10/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 879.6748
# Epoch 11/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 878.2877
# Epoch 12/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 876.9016
# Epoch 13/2000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 875.5166
# Epoch 14/2000
# ...

# %%
import numpy as np  # Import NumPy

예측값 = model.predict(np.array([[15]])) # Convert the list to a NumPy array
print(예측값)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# [[30.622911]]
